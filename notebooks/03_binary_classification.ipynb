# %% [markdown]
# # Classificazione binaria: Alzheimer vs Non-Alzheimer
# Questo notebook esegue l'addestramento e la valutazione di due modelli di Deep Learning per la classificazione binaria di immagini MRI cerebrali:
# * CNN custom (baseline)
# * ResNet50 (Transfer Learning)

# %%
# Se usi Google Colab, monta il drive; altrimenti ignora senza errori
try:
	from google.colab import drive
	drive.mount('/content/drive')
except Exception:
	print("Non in Google Colab: saltato il mount di Drive.")
# Out:
# Non in Google Colab: saltato il mount di Drive.

# %%
# !pip install torch torchvision scikit-learn matplotlib
# !pip install -e .
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Obtaining file:///C:/Users/macca/Desktop/universit%C3%A0/magistrale/deep%20learning/unict-dlcmm-Maccarrone-Brancaforte-Cassia/notebooks
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: file:///C:/Users/macca/Desktop/universit%C3%A0/magistrale/deep%20learning/unict-dlcmm-Maccarrone-Brancaforte-Cassia/notebooks does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

from torchvision import models, transforms, datasets
from torch.utils.data import DataLoader
from sklearn.metrics import classification_report, confusion_matrix

import sys
repo_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if repo_root not in sys.path:
	sys.path.insert(0, repo_root)

from src.data.dataloaders import get_dataloader
from src.utils.helpers import set_seed, get_device

# %%
set_seed(42)
device = get_device()

#DATA_DIR = '/content/drive/MyDrive/data/processed/binary'
DATA_DIR = os.path.join(repo_root, 'data', 'processed', 'binary')
BATCH_SIZE = 32
EPOCHS = 10
LR = 1e-4
