# %%
# installazioni
# %pip install -e .
# %pip install torchvision torch
# Out:
# Obtaining file:///C:/Users/macca/Desktop/universit%C3%A0/magistrale/deep%20learning/unict-dlcmm-Maccarrone-Brancaforte-Cassia/notebooks
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: file:///C:/Users/macca/Desktop/universit%C3%A0/magistrale/deep%20learning/unict-dlcmm-Maccarrone-Brancaforte-Cassia/notebooks does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# librerie
import sys
import os

repo_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if repo_root not in sys.path:
	sys.path.insert(0, repo_root)

from src.data.preprocessing import create_binary_dataset

# %%
RAW_DIR = "../data/raw/AugmentedAlzheimerDataset"
PROCESSED_BINARY_DIR_BIN = "../data/processed/binary"
PROCESSED_BINARY_DIR_MULT = "../data/processed/multiclass"

# %% [markdown]
# ## Dati per classificazione binaria

# %%
create_binary_dataset(RAW_DIR, PROCESSED_BINARY_DIR_BIN)

# %%
for cls in os.listdir(PROCESSED_BINARY_DIR_BIN):
    print(cls, len(os.listdir(os.path.join(PROCESSED_BINARY_DIR_BIN, cls))))
# Out:
# Alzheimer 24384
# NonAlzheimer 9600

# %% [markdown]
# Problema: le due classi sono sbilanciate.

# %%
# preprocessing per classificazione binaria

# %% [markdown]
# ## Dati per classificazione multiclasse
